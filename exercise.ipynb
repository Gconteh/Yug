# %% [markdown]
# # 1.a

# %%
import pandas as pd
movies =pd.read_csv('imdb_1000.csv')

# %%
movies[movies.content_rating.isnull()]
# there 3 missing values in the 'content_value' column
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %% [markdown]
# # 1.b

# %%
movies.isnull().sum()
# there are 3 rows containing missing values
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %% [markdown]
# # 1.c

# %%
movies.content_rating.unique()
# Out:
# array(['R', 'PG-13', 'NOT RATED', 'PG', 'UNRATED', 'APPROVED', 'PASSED',
#        'G', 'X', nan, 'TV-MA', 'GP', 'NC-17'], dtype=object)

# %% [markdown]
# # 1.d

# %%
movies.loc[movies['content_rating'] =='NOT RATED' ]
# There are 65 movies which are not rated
# Out:
#      star_rating                             title content_rating      genre  \
# 5            8.9                      12 Angry Men      NOT RATED      Drama
# 6            8.9    The Good, the Bad and the Ugly      NOT RATED    Western
# 41           8.5                      Sunset Blvd.      NOT RATED      Drama
# 63           8.4                                 M      NOT RATED      Crime
# 66           8.4               Munna Bhai M.B.B.S.      NOT RATED     Comedy
# 72           8.4                   Rang De Basanti      NOT RATED      Drama
# 83           8.4             To Kill a Mockingbird      NOT RATED      Drama
# 87           8.4                   Bicycle Thieves      NOT RATED      Drama
# 88           8.4                           The Kid      NOT RATED     Comedy
# 89           8.4                            Swades      NOT RATED      Drama
# 93           8.4       Dilwale Dulhania Le Jayenge      NOT RATED     Comedy
# ...

# %% [markdown]
# # 1.e

# %%
movies.loc[movies['star_rating'] > 9 ]
# there are 3 movies with higher ratings than 9
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %% [markdown]
# # 2.

# %%
import pandas as pd
drinkss = pd.read_csv('drinks.csv')

# %%
drinkss['total'] = drinkss['beer_servings']+ drinkss['spirit_servings']

# %%
drinks =drinkss.head()

# %%
drinks.sort_values([ 'total'],ascending=False)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 0  Afghanistan              0                0              0
#
#    total_litres_of_pure_alcohol continent  total
# 3                          12.4    Europe    383
# 4                           5.9    Africa    274
# 1                           4.9    Europe    221
# 2                           0.7    Africa     25
# 0                           0.0      Asia      0

# %% [markdown]
# # 3.

# %%
drinkss.groupby('continent').sum()
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa                  3258              866            862
# Asia                    1630             2677            399
# Europe                  8720             5965           6400
# North America           3345             3812            564
# Oceania                 1435              935            570
# South America           2101             1377            749
#
#                total_litres_of_pure_alcohol  total
# continent
# Africa                                159.4   4986
# Asia                                   95.5   4706
# Europe                                387.8  21085
# North America                         137.9   7721
# Oceania                                54.1   2940
# South America                          75.7   4227

# %% [markdown]
# # 4.

# %%
drinkss.groupby('continent').max()
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# continent
# Africa               Zimbabwe            376              152            233
# Asia                    Yemen            247              326            123
# Europe         United Kingdom            361              373            370
# North America             USA            285              438            100
# Oceania               Vanuatu            306              254            212
# South America       Venezuela            333              302            221
#
#                total_litres_of_pure_alcohol  total
# continent
# Africa                                  9.1    504
# Asia                                   11.5    646
# Europe                                 14.4    695
# North America                          11.9    665
# Oceania                                10.4    545
# South America                           8.3    439

# %% [markdown]
# # 5.

# %%
drinkss.loc[drinkss['continent'] =='Africa' ]
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# 2                     Algeria             25                0             14
# 4                      Angola            217               57             45
# 18                      Benin             34                4             13
# 22                   Botswana            173               35             35
# 26               Burkina Faso             25                7              7
# 27                    Burundi             88                0              0
# 28              Cote d'Ivoire             37                1              7
# 29                 Cabo Verde            144               56             16
# 31                   Cameroon            147                1              4
# 33   Central African Republic             17                2              1
# 34                       Chad             15                1              1
# ...

# %%
driik = drinkss.loc[drinkss['continent'] =='Africa' ].copy()

# %%
driik.sort_values([ 'total_litres_of_pure_alcohol'],ascending=False)
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# 124                   Nigeria             42                5              2
# 62                      Gabon            347               98             59
# 179                    Uganda             45                9              0
# 159              South Africa            225               76             81
# 142                    Rwanda             43                2              0
# 117                   Namibia            376                3              1
# 153              Sierra Leone             25                3              2
# 27                    Burundi             88                0              0
# 4                      Angola            217               57             45
# 55          Equatorial Guinea             92                0            233
# 31                   Cameroon            147                1              4
# ...

# %%
# Mauritania is the west African country with the lowest amount of litres of pure alcohol.

# %% [markdown]
# # 6.

# %%
driik.sort_values([ 'total_litres_of_pure_alcohol'],ascending=False)
# Uganda is the east African country which has the highest intake of alcohol
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# 124                   Nigeria             42                5              2
# 62                      Gabon            347               98             59
# 179                    Uganda             45                9              0
# 159              South Africa            225               76             81
# 142                    Rwanda             43                2              0
# 117                   Namibia            376                3              1
# 153              Sierra Leone             25                3              2
# 27                    Burundi             88                0              0
# 4                      Angola            217               57             45
# 55          Equatorial Guinea             92                0            233
# 31                   Cameroon            147                1              4
# ...

# %% [markdown]
# # 7.

# %%
import pandas as pd
titanic =pd.read_csv('titanic_train.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
titanic.Age.mean()
# Out:
# 29.69911764705882

# %%
titanic.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
titanic.loc[titanic['Pclass'] == 3 ]
# the most common Pclass is 3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 10            11         1       3
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 16            17         0       3
# 18            19         0       3
# 19            20         1       3
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 32            33         1       3
# 36            37         1       3
# 37            38         0       3
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# ...

# %%
titanic.loc[titanic.duplicated (keep = 'first')]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
titanic.loc[titanic['Sex'] == 'male' ]
# the most common sex is male
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 4              5         0       3                 Allen, Mr. William Henry
# 5              6         0       3                         Moran, Mr. James
# 6              7         0       1                  McCarthy, Mr. Timothy J
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 12            13         0       3           Saundercock, Mr. William Henry
# 13            14         0       3              Andersson, Mr. Anders Johan
# 16            17         0       3                     Rice, Master. Eugene
# 17            18         1       2             Williams, Mr. Charles Eugene
# 20            21         0       2                     Fynney, Mr. Joseph J
# 21            22         1       2                    Beesley, Mr. Lawrence
# ...

# %% [markdown]
# # 8.

# %%
titanic.groupby('Sex').sum()
# female recorded most survivors
# Out:
#         PassengerId  Survived  Pclass       Age  SibSp  Parch        Fare
# Sex
# female       135343       233     678   7286.00    218    204  13966.6628
# male         262043       109    1379  13919.17    248    136  14727.2865

# %% [markdown]
# # 9.

# %%
driik.sort_values([ 'total_litres_of_pure_alcohol'],ascending=False)
# Tunisia is the north african country which drinks most
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# 124                   Nigeria             42                5              2
# 62                      Gabon            347               98             59
# 179                    Uganda             45                9              0
# 159              South Africa            225               76             81
# 142                    Rwanda             43                2              0
# 117                   Namibia            376                3              1
# 153              Sierra Leone             25                3              2
# 27                    Burundi             88                0              0
# 4                      Angola            217               57             45
# 55          Equatorial Guinea             92                0            233
# 31                   Cameroon            147                1              4
# ...

# %% [markdown]
# # 10.

# %%
# the 3rd country in SADC in consuming alcohol is Angola

# %% [markdown]
# # 11.

# %%
import pandas as pd
ufo = pd.read_csv('ufo.csv')

# %%
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %% [markdown]
# # 12.

# %%
drinks
# japan is the country in G7 which has the lowest intake of alcohol
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent  total
# 0                           0.0      Asia      0
# 1                           4.9    Europe    221
# 2                           0.7    Africa     25
# 3                          12.4    Europe    383
# 4                           5.9    Africa    274

# %% [markdown]
# # 13.

# %%
movies
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
movies.groupby('genre').sum()
# Out:
#            star_rating  duration
# genre
# Action          1072.3     17202
# Adventure        595.0     10113
# Animation        490.7      5989
# Biography        605.4     10152
# Comedy          1220.3     16786
# Crime            981.7     15165
# Drama           2196.9     35178
# Family            15.7       215
# Fantasy            7.7       112
# Film-Noir         24.1       292
# History            8.0        66
# Horror           226.4      2973
# Mystery          127.6      1850
# Sci-Fi            39.6       545
# Thriller          38.4       571
# Western           74.3      1230

# %%
import pandas as pd
females =pd.read_csv('daily-total-female-births.csv')

# %%
females.head()
# Out:
#          Date  Births
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44
